# %% [markdown]
# <b>Вариант 15</b>

# %% [markdown]
# <b>1. Для заданного пользователя рассчитать оценки для всех
# фильмов, которые он не оценил.</b>

# %%
import pandas as pd
import numpy as np
import math
import json
from collections import defaultdict

# %%
#User 15 будет находиться на строке 14
user15=15
v=user15-1
k=4

# %%
#Считываем файлы
data=pd.read_csv('data.csv')
context_day=pd.read_csv('context_day.csv')
context_place=pd.read_csv('context_place.csv')
movie_names=pd.read_csv('movie_names.csv')

# %%
#Удаляем столбец с юзерами
data = data.drop(data.columns[0], axis=1)

# %%
data
# Out:
#      Movie 1   Movie 2   Movie 3   Movie 4   Movie 5   Movie 6   Movie 7  \
# 0         -1         4         1         5        -1        -1        -1
# 1          4         5         2         3         3         4        -1
# 2          4         2         5         4         1         5        -1
# 3          5        -1         2        -1        -1         2         4
# 4          4         3         3         3         5         3         3
# 5          2        -1         3         3         3         3         4
# 6          4         1         4         4         1         4         5
# 7         -1         5         5         3         3         3         3
# 8          1         2         3         1         5         3         3
# 9          5        -1         1        -1         3         3         4
# 10        -1         5        -1         1         5         2         4
# 11         5         4         4        -1         3        -1         5
# 12         1         1         4         5         4         3         5
# 13         3         5         4        -1         1         2         4
# 14         3         5         3         4         4        -1         4
# 15         3         3         5         3         2         2         5
# 16         1         1        -1        -1         4         4        -1
# 17         4         3         3         2         1         5         3
# 18         4         3         5         5         4         4        -1
# 19         2        -1         2         5        -1        -1         1
# 20        -1         2         1         2         3         5         4
# 21         2         4         4        -1         4        -1         4
# 22         5         1        -1         5         5        -1        -1
# 23         5         4         2        -1         2         1         3
# 24         3         1        -1         4         2        -1         4
# 25         1         5        -1         3        -1         2         4
# 26         4         4         3        -1         4         5         3
# 27        -1        -1         4         2         3         2         1
# 28         3         2         4         2         2         2         4
# 29         2         3         5         4         1         3         3
# 30         3         5         4         5         1         3         3
# 31         5         4         5         4         1         5         5
# 32         5         3         4         4         2         1         3
# 33        -1         5        -1        -1         1        -1         5
# 34         4        -1         5         4         2         2         3
# 35         3         2        -1         5         5         1         5
# 36        -1         4        -1         3         1         4         5
# 37         3        -1         1         4         2         3         4
# 38         1        -1         5        -1         1         2         3
# 39        -1         1         1         1         1        -1         4
#
#      Movie 8   Movie 9   Movie 10  ...   Movie 21   Movie 22   Movie 23  \
# 0          1         3         -1  ...          2          4         -1
# 1          5         3          2  ...         -1          2         -1
# 2          3         5          2  ...          4         -1          5
# 3          3         2          3  ...         -1          2          2
# 4          4         5          2  ...          4          5          2
# 5          2        -1          1  ...          5         -1          1
# 6          2         2         -1  ...          2          5          1
# 7          3         1          2  ...         -1          3          1
# 8          1         2          5  ...          3          2          3
# 9          1         1          2  ...          4          1          4
# 10         2         4         -1  ...          4         -1          3
# 11         5         5          3  ...          1          4          1
# 12         5         5          4  ...          2          3          2
# 13        -1        -1          4  ...          4          1          5
# 14         4         2          1  ...          2          2          5
# 15        -1         4          4  ...          1          3          4
# 16        -1         1          1  ...          4          2          4
# 17         4         5          2  ...         -1          4          5
# 18        -1         4          4  ...          2          3          1
# 19        -1         2         -1  ...         -1          2          4
# 20         1         2          3  ...         -1          5          1
# 21         5         5          4  ...          4          5          1
# 22         5        -1          3  ...         -1         -1          3
# 23         2         1          2  ...          4          2          2
# 24         1         5          3  ...          2         -1          5
# 25        -1         4          2  ...          5          3          1
# 26         4         3         -1  ...         -1          3          4
# 27         4        -1          1  ...          1          3          2
# 28         1         3          3  ...          3         -1          3
# 29         2         3          1  ...          4          5          1
# 30         3         4          1  ...          5          4          4
# 31         4         4         -1  ...          5          2         -1
# 32         1         3          3  ...          2          1          5
# 33         1         1          5  ...          3          3          4
# 34         1         1          5  ...          5          1          2
# 35         2         1          5  ...         -1          2          4
# 36         4         3          3  ...          3          3         -1
# 37        -1         5          3  ...          5          4          3
# 38        -1         2          5  ...          4          2          5
# 39         1        -1          3  ...          3          5          4
#
#      Movie 24   Movie 25   Movie 26   Movie 27   Movie 28   Movie 29  \
# 0          -1          3          4         -1          2          4
# 1           3          1          5         -1          5          2
# 2           4          5          1          2          1         -1
# 3           2          2          5          3          2          5
# 4          -1          3          5          1         -1          5
# 5           3         -1          4          4          5          1
# 6           3          4         -1          4          3          1
# 7           3          2          1          4         -1          1
# 8          -1          1          4          3          1          5
# 9           1          4          5          2          3         -1
# 10          4          1          2          4          2          5
# 11          5          3          5          4          3          5
# 12         -1          4          3         -1          5          5
# 13          4          1         -1          3          1          5
# 14          1          3          4         -1         -1          5
# 15         -1          4          4          4          2          4
# 16          2          2         -1          5          4          5
# 17          2          1          1          2          1         -1
# 18          2         -1          2          5          1          2
# 19          1         -1          2          2          3          3
# 20          2          5          5          4          4          2
# 21         -1         -1          5          2          2          5
# 22          1          5         -1          1          5          3
# 23          1          3          2          5          2          5
# 24          5          2         -1          1          3          1
# 25          5          2         -1          2          2          4
# 26          3         -1          3          2          3          2
# 27          1          4          3          2          4          2
# 28          5          5          5          4         -1          5
# 29          1          4          5          3          1          3
# 30          3          5          2          2          4          4
# 31          2          3          2          1          3          1
# 32          5          2         -1          2          1          4
# 33         -1          3          1          5          2          2
# 34          1          5          5          1         -1          5
# 35          3          4          5          2          1          3
# 36          5         -1          5          2          3          5
# 37         -1          1          4          3         -1         -1
# 38          2          3          1          2          1          2
# 39          2          3          4          5          5          3
#
#      Movie 30
# 0           1
# 1           2
# 2           3
# 3           5
# 4          -1
# 5           2
# 6           4
# 7           3
# 8           3
# 9           1
# 10          1
# 11          5
# 12          4
# 13          3
# 14          4
# 15          4
# 16          3
# 17          4
# 18          1
# 19          4
# 20         -1
# 21         -1
# 22          5
# 23          4
# 24          2
# 25         -1
# 26          5
# 27          1
# 28         -1
# 29          5
# 30         -1
# 31         -1
# 32          2
# 33          5
# 34          5
# 35          4
# 36         -1
# 37          4
# 38          1
# 39          2
#
# [40 rows x 30 columns]

# %%
sim=np.zeros(data.shape[0])

# %%
#В качестве метрики сходства используем метрику косинуса
for u in range(data.shape[0]):
    if (u!=v):
        sumuv=0
        sumu2=0
        sumv2=0
        uv = data.iloc[[u, v]]
        uv=uv.transpose()
        for i,movie in uv.iterrows():
            if ((movie[u] != -1) & (movie[v] != -1 )):
                sumuv=sumuv+movie[u]*movie[v]
                sumu2=sumu2+pow(movie[u],2)
                sumv2=sumv2+pow(movie[v],2)
        sim[u] = sumuv / ((math.sqrt(sumu2) * math.sqrt(sumv2)))

# %%
sim
# Out:
# array([0.89165108, 0.82728141, 0.8032582 , 0.93180871, 0.84481728,
#        0.81604659, 0.76855679, 0.85707636, 0.84465498, 0.84781132,
#        0.8380006 , 0.85198511, 0.83405245, 0.907311  , 0.        ,
#        0.86497836, 0.80873608, 0.85070191, 0.80286955, 0.82655401,
#        0.7893389 , 0.8294219 , 0.85353758, 0.88729747, 0.76322622,
#        0.81442674, 0.88391241, 0.84815569, 0.85721515, 0.87102783,
#        0.82446069, 0.83846797, 0.84622694, 0.86032214, 0.81275369,
#        0.86055777, 0.89205814, 0.86411342, 0.79303945, 0.79466915])

# %%
#Выбираем 4 наиболее похожих пользователя
sim4 = np.argpartition(sim, -k)[-k:]

# %%
sim4
# Out:
# array([ 0, 36,  3, 13], dtype=int32)

# %%
#Средняя оценка у пользователя user
def means(user):
    mylist = []
    for i in range(data.shape[1]):
        if data.iloc[user][i] != -1:
            mylist.append(data.iloc[user][i])
    arr=np.array(mylist)
    return np.mean(arr)

# %%
#Массив неоцененных фильмов user 15
mylist = []
for i in range(data.shape[1]):
    if (data.iloc[v][i] == -1):
        mylist.append(i)
unrated_films=np.array(mylist)

unrated_films
# Out:
# array([ 5, 10, 11, 19, 26, 27])

# %%
#Расчет оценки rui пользователя
dict_rates={}
for film in unrated_films:
    sumsimr=0
    sumsim=0
    for u in sim4:
        if (data.iloc[u, film] != -1):
            sumsimr=sumsimr+sim[u] * (data.iloc[u, film] - means(u))
            sumsim=sumsim+sim[u]
    dict_rates[film] = round(means(v) + sumsimr/sumsim, 3)
    
dict_rates
# Out:
# {5: 2.898, 10: 3.308, 11: 3.308, 19: 2.299, 26: 2.918, 27: 2.284}

# %%
#Ответ в более понятном виде
rates={}
for i in dict_rates.keys():
    rates['Movie '+str(i+1)]=dict_rates[i]

# %%
rates
# Out:
# {'Movie 6': 2.898,
#  'Movie 11': 3.308,
#  'Movie 12': 3.308,
#  'Movie 20': 2.299,
#  'Movie 27': 2.918,
#  'Movie 28': 2.284}

# %% [markdown]
# <b>2. Порекомендовать заданному пользователю 1
# фильм, который он посмотрел бы в выходной дома,
# если такой фильм есть в данных.</b>

# %%
#Удаляем столбец с юзерами
context_day = context_day.drop(context_day.columns[0], axis=1)

# %%
context_day
# Out:
#     Movie 1  Movie 2  Movie 3  Movie 4  Movie 5  Movie 6  Movie 7  Movie 8  \
# 0        -1      Thu      Tue      Mon       -1       -1       -1      Tue
# 1       Mon      Wed      Mon      Sat      Sat      Thu       -1      Mon
# 2       Tue      Wed      Sat      Tue      Sat      Mon       -1      Thu
# 3       Mon       -1      Wed       -1       -1      Sun      Sat      Mon
# 4       Thu      Fri      Wed      Fri      Mon      Thu      Sat      Tue
# 5       Mon       -1      Tue      Sat      Fri      Fri      Mon      Sun
# 6       Thu      Tue      Sat      Fri      Sun      Sun      Fri      Wed
# 7        -1      Sun      Fri      Sat      Fri      Thu      Thu      Tue
# 8       Sat      Sun      Thu      Thu      Tue      Wed      Mon      Tue
# 9       Sun       -1      Tue       -1      Mon      Fri      Thu      Tue
# 10       -1      Sun       -1      Sun      Fri      Thu      Tue      Thu
# 11      Sun      Tue      Sat       -1      Sat       -1      Wed      Wed
# 12      Mon      Tue      Fri      Sat      Fri      Thu      Mon      Sun
# 13      Sat      Fri      Mon       -1      Thu      Wed      Mon       -1
# 14      Sat      Fri      Fri      Tue      Sat       -1      Mon      Sat
# 15      Tue      Sat      Thu      Sun      Sat      Wed      Sun       -1
# 16      Fri      Sun       -1       -1      Thu      Fri       -1       -1
# 17      Fri      Sat      Thu      Thu      Mon      Thu      Tue      Sat
# 18      Tue      Sun      Wed      Sun      Sun      Wed       -1       -1
# 19      Wed       -1      Sun      Mon       -1       -1      Mon       -1
# 20       -1      Thu      Thu      Sat      Sat      Thu      Thu      Sat
# 21      Fri      Fri      Tue       -1      Mon       -1      Fri      Wed
# 22      Fri      Mon       -1      Thu      Sat       -1       -1      Wed
# 23      Fri      Thu      Mon       -1      Sun      Thu      Sat      Wed
# 24      Thu      Wed       -1      Fri      Mon       -1      Thu      Thu
# 25      Sun      Sat       -1      Wed       -1      Mon      Wed       -1
# 26      Sun      Fri      Thu       -1      Mon      Tue      Wed      Tue
# 27       -1       -1      Mon      Wed      Fri      Mon      Tue      Mon
# 28      Sat      Mon      Sat      Sat      Sun      Sun      Thu      Sun
# 29      Sun      Sun      Fri      Wed      Sat      Tue      Fri      Thu
# 30      Fri      Tue      Sat      Thu      Mon      Fri      Mon      Tue
# 31      Mon      Mon      Fri      Sun      Mon      Sun      Fri      Thu
# 32      Sat      Sat      Mon      Tue      Fri      Thu      Wed      Mon
# 33       -1      Sat       -1       -1      Mon       -1      Sat      Wed
# 34      Fri       -1      Sun      Thu      Sun      Thu      Tue      Thu
# 35      Wed      Tue       -1      Sun      Thu      Thu      Sat      Sun
# 36       -1      Fri       -1      Wed      Fri      Mon      Fri      Mon
# 37      Mon       -1      Tue      Sun      Thu      Sun      Fri       -1
# 38      Sat       -1      Mon       -1      Thu      Mon      Mon       -1
# 39       -1      Fri      Tue      Mon      Fri       -1      Sun      Thu
#
#     Movie 9  Movie 10  ...  Movie 21  Movie 22  Movie 23  Movie 24  Movie 25  \
# 0       Sun        -1  ...       Thu       Thu        -1        -1       Sun
# 1       Fri       Thu  ...        -1       Sun        -1       Mon       Mon
# 2       Wed       Thu  ...       Tue        -1       Wed       Thu       Tue
# 3       Mon       Wed  ...        -1       Sun       Fri       Sat       Thu
# 4       Thu       Fri  ...       Fri       Fri       Mon        -1       Wed
# 5        -1       Thu  ...       Thu        -1       Wed       Wed        -1
# 6       Mon        -1  ...       Tue       Sun       Sun       Tue       Wed
# 7       Sat       Wed  ...        -1       Sat       Fri       Tue       Fri
# 8       Sat       Mon  ...       Wed       Wed       Tue        -1       Fri
# 9       Thu       Fri  ...       Thu       Tue       Sun       Thu       Thu
# 10      Thu        -1  ...       Sun        -1       Tue       Sun       Mon
# 11      Sat       Tue  ...       Thu       Wed       Fri       Sun       Thu
# 12      Thu       Wed  ...       Thu       Tue       Sat        -1       Thu
# 13       -1       Sun  ...       Sat       Sat       Wed       Sat       Mon
# 14      Fri       Mon  ...       Sun       Fri       Sat       Sat       Tue
# 15      Mon       Thu  ...       Tue       Fri       Tue        -1       Tue
# 16      Wed       Thu  ...       Thu       Tue       Mon       Sun       Mon
# 17      Wed       Sun  ...        -1       Thu       Fri       Wed       Wed
# 18      Sat       Wed  ...       Fri       Fri       Tue       Thu        -1
# 19      Wed        -1  ...        -1       Sat       Wed       Tue        -1
# 20      Fri       Fri  ...        -1       Tue       Wed       Wed       Sat
# 21      Tue       Sun  ...       Sun       Wed       Mon        -1        -1
# 22       -1       Wed  ...        -1        -1       Wed       Sat       Tue
# 23      Wed       Mon  ...       Thu       Sun       Mon       Sun       Wed
# 24      Fri       Mon  ...       Tue        -1       Thu       Sat       Mon
# 25      Wed       Mon  ...       Mon       Wed       Tue       Sat       Thu
# 26      Fri        -1  ...        -1       Mon       Tue       Sun        -1
# 27       -1       Wed  ...       Sun       Wed       Mon       Tue       Tue
# 28      Fri       Tue  ...       Tue        -1       Fri       Sat       Sat
# 29      Wed       Sat  ...       Sat       Fri       Tue       Thu       Tue
# 30      Sat       Sat  ...       Wed       Sat       Sat       Sat       Tue
# 31      Mon        -1  ...       Mon       Thu        -1       Tue       Thu
# 32      Wed       Sat  ...       Mon       Thu       Wed       Thu       Thu
# 33      Wed       Sun  ...       Tue       Thu       Sat        -1       Mon
# 34      Sat       Fri  ...       Sun       Sun       Sat       Sun       Sun
# 35      Tue       Sun  ...        -1       Tue       Fri       Thu       Sat
# 36      Fri       Mon  ...       Tue       Fri        -1       Fri        -1
# 37      Thu       Tue  ...       Thu       Fri       Sun        -1       Fri
# 38      Mon       Sat  ...       Thu       Mon       Sat       Sun       Sun
# 39       -1       Tue  ...       Mon       Tue       Sat       Sun       Sun
#
#     Movie 26  Movie 27  Movie 28  Movie 29  Movie 30
# 0        Sat        -1       Wed       Wed       Thu
# 1        Fri        -1       Sun       Tue       Wed
# 2        Thu       Wed       Wed        -1       Sun
# 3        Sat       Fri       Fri       Sat       Sun
# 4        Mon       Sat        -1       Wed        -1
# 5        Wed       Sun       Thu       Sat       Mon
# 6         -1       Fri       Tue       Wed       Wed
# 7        Sun       Thu        -1       Sun       Wed
# 8        Thu       Fri       Wed       Sun       Mon
# 9        Sun       Sat       Tue        -1       Mon
# 10       Fri       Sat       Sat       Tue       Thu
# 11       Thu       Wed       Mon       Wed       Mon
# 12       Tue        -1       Sun       Wed       Wed
# 13        -1       Wed       Sat       Thu       Sun
# 14       Thu        -1        -1       Mon       Sun
# 15       Sat       Thu       Tue       Sat       Sat
# 16        -1       Sun       Fri       Wed       Mon
# 17       Mon       Mon       Tue        -1       Mon
# 18       Sat       Sun       Sun       Sat       Wed
# 19       Fri       Thu       Mon       Fri       Tue
# 20       Mon       Sun       Sat       Sun        -1
# 21       Fri       Mon       Fri       Thu        -1
# 22        -1       Thu       Mon       Thu       Thu
# 23       Mon       Fri       Thu       Fri       Wed
# 24        -1       Thu       Fri       Sat       Sat
# 25        -1       Thu       Sat       Mon        -1
# 26       Sun       Wed       Thu       Sat       Mon
# 27       Thu       Fri       Sun       Tue       Mon
# 28       Wed       Sun        -1       Mon        -1
# 29       Thu       Fri       Sun       Thu       Wed
# 30       Sat       Sun       Tue       Wed        -1
# 31       Mon       Sat       Tue       Thu        -1
# 32        -1       Fri       Sun       Tue       Wed
# 33       Mon       Tue       Thu       Sun       Thu
# 34       Fri       Mon        -1       Fri       Sat
# 35       Sun       Thu       Thu       Sun       Sat
# 36       Sun       Sun       Wed       Sun        -1
# 37       Tue       Sun        -1        -1       Mon
# 38       Thu       Fri       Wed       Fri       Sat
# 39       Tue       Wed       Mon       Sun       Thu
#
# [40 rows x 30 columns]

# %%
#Удаляем столбец с юзерами
context_place = context_place.drop(context_place.columns[0], axis=1)

# %%
context_place
# Out:
#     Movie 1  Movie 2  Movie 3  Movie 4  Movie 5  Movie 6  Movie 7  Movie 8  \
# 0        -1        h        h        c       -1       -1       -1        v
# 1         v        v        v        v        h        c       -1        v
# 2         v        h        c        c        c        c       -1        h
# 3         v       -1        h       -1       -1        h        v        v
# 4         c        c        c        c        v        h        v        v
# 5         c       -1        c        h        v        c        v        v
# 6         v        h        v        c        c        v        c        c
# 7        -1        h        c        h        h        v        h        h
# 8         h        c        h        v        h        h        v        c
# 9         v       -1        v       -1        v        c        h        c
# 10       -1        c       -1        h        h        h        v        v
# 11        h        v        h       -1        h       -1        c        v
# 12        h        c        v        v        c        c        c        h
# 13        v        c        v       -1        v        v        c       -1
# 14        v        c        v        h        v       -1        h        v
# 15        h        v        c        c        c        c        v       -1
# 16        v        v       -1       -1        h        c       -1       -1
# 17        h        h        h        h        h        c        h        h
# 18        h        c        v        h        c        c       -1       -1
# 19        v       -1        h        v       -1       -1        h       -1
# 20       -1        c        c        c        h        c        v        v
# 21        c        c        h       -1        v       -1        v        c
# 22        c        v       -1        c        v       -1       -1        v
# 23        c        v        v       -1        v        c        c        c
# 24        c        h       -1        c        v       -1        v        c
# 25        v        v       -1        v       -1        h        v       -1
# 26        h        h        v       -1        h        v        v        h
# 27       -1       -1        v        h        h        h        c        v
# 28        v        c        c        v        h        h        c        v
# 29        c        h        c        c        v        c        h        c
# 30        v        h        v        h        c        v        v        c
# 31        c        v        v        v        h        c        h        h
# 32        h        v        c        v        h        c        c        h
# 33       -1        h       -1       -1        c       -1        c        c
# 34        v       -1        h        c        h        v        h        c
# 35        c        h       -1        c        h        v        h        c
# 36       -1        v       -1        h        c        h        c        c
# 37        v       -1        v        h        c        v        h       -1
# 38        c       -1        v       -1        h        v        v       -1
# 39       -1        c        v        c        h       -1        c        v
#
#     Movie 9  Movie 10  ...  Movie 21  Movie 22  Movie 23  Movie 24  Movie 25  \
# 0         h        -1  ...         h         c        -1        -1         c
# 1         h         c  ...        -1         c        -1         c         h
# 2         c         v  ...         v        -1         v         v         h
# 3         c         h  ...        -1         v         h         h         c
# 4         c         h  ...         v         c         v        -1         h
# 5        -1         c  ...         h        -1         c         h        -1
# 6         v        -1  ...         h         c         c         c         v
# 7         v         c  ...        -1         v         c         v         h
# 8         c         h  ...         c         v         h        -1         v
# 9         h         v  ...         c         v         h         v         c
# 10        c        -1  ...         c        -1         h         v         c
# 11        v         v  ...         c         c         h         c         v
# 12        c         c  ...         v         v         c        -1         c
# 13       -1         c  ...         v         v         v         v         c
# 14        c         c  ...         h         c         h         c         h
# 15        h         h  ...         v         h         h        -1         h
# 16        v         h  ...         v         v         c         c         h
# 17        v         v  ...        -1         v         h         c         v
# 18        v         h  ...         c         v         h         v        -1
# 19        v        -1  ...        -1         c         v         c        -1
# 20        v         h  ...        -1         c         h         v         v
# 21        v         h  ...         c         v         h        -1        -1
# 22       -1         c  ...        -1        -1         c         c         h
# 23        h         h  ...         v         c         h         h         c
# 24        v         v  ...         h        -1         v         h         h
# 25        c         c  ...         c         v         v         h         h
# 26        h        -1  ...        -1         v         v         v        -1
# 27       -1         h  ...         h         c         v         v         c
# 28        v         h  ...         c        -1         c         h         h
# 29        h         h  ...         v         v         c         v         c
# 30        v         c  ...         c         v         c         c         v
# 31        c        -1  ...         h         v        -1         c         c
# 32        h         c  ...         v         h         v         h         c
# 33        v         h  ...         c         c         v        -1         c
# 34        c         c  ...         v         c         c         c         v
# 35        c         v  ...        -1         c         v         v         v
# 36        h         v  ...         h         c        -1         v        -1
# 37        c         h  ...         v         c         c        -1         c
# 38        c         v  ...         v         v         v         h         c
# 39       -1         v  ...         v         h         c         v         h
#
#     Movie 26  Movie 27  Movie 28  Movie 29  Movie 30
# 0          c        -1         v         h         c
# 1          v        -1         v         v         c
# 2          h         h         v        -1         v
# 3          v         c         v         v         c
# 4          c         v        -1         h        -1
# 5          h         h         h         c         c
# 6         -1         v         h         h         c
# 7          h         c        -1         h         c
# 8          h         v         c         h         h
# 9          v         v         h        -1         c
# 10         c         h         c         c         c
# 11         h         h         v         c         v
# 12         h        -1         c         v         v
# 13        -1         v         c         h         h
# 14         c        -1        -1         h         v
# 15         c         v         v         h         c
# 16        -1         v         h         h         h
# 17         v         c         h        -1         h
# 18         c         h         c         c         c
# 19         v         h         c         h         v
# 20         v         v         h         c        -1
# 21         h         v         v         v        -1
# 22        -1         c         h         c         c
# 23         v         c         c         v         h
# 24        -1         v         c         c         v
# 25        -1         c         c         v        -1
# 26         c         c         h         c         h
# 27         c         h         h         c         v
# 28         c         h        -1         v        -1
# 29         h         c         c         c         h
# 30         h         v         v         h        -1
# 31         h         c         v         h        -1
# 32        -1         v         c         v         c
# 33         v         c         c         c         h
# 34         h         v        -1         c         v
# 35         h         h         h         h         v
# 36         v         c         c         c        -1
# 37         c         v        -1        -1         h
# 38         h         c         v         v         c
# 39         v         c         c         c         c
#
# [40 rows x 30 columns]

# %%
#фильмы, просмотренные дома
home=[' h']
#фильмы, просмотренные на выходных
weekends=[' Sun',' Sat']

# %%
#Для того, чтобы порекомендовать фильм, смотрим на то, как часто каждый фильм смотрелся дома и в выходные
#home_ind - как часто фильм смотрелся дома
#weekends_ind - как часто фильм смотрелся в выходные
_default_data = lambda: defaultdict(_default_data)
data_films = _default_data()
for film in unrated_films:
    home_ind=0 #просмотры фильма дома
    weekends_ind=0 #просмотры фильма на выходных
    total=0 #просмотры фильма
    for user in range(data.shape[0]):
        if (context_place.iloc[user][film] in home):
            home_ind+=1
        if (context_day.iloc[user][film] in weekends):
            weekends_ind+=1
        if (context_place.iloc[user][film] != -1):
            total+=1
    data_films[int(film)]['home_ind']=round(home_ind/total,3)
    data_films[int(film)]['weekends_ind']=round(weekends_ind/total,3)  
    data_films[int(film)]['rate']=dict_rates[film]

# %%
films={}
for i in dict_rates.keys():
    films['Movie '+str(i+1)]=data_films[i]

# %%
#получаем словарь с фильмом и его индексом просмотра дома, индексом просмотра на выходных, рейтингом
print(json.dumps(films, indent=2))
# Out:
# {
#   "Movie 6": {
#     "home_ind": 0.2,
#     "weekends_ind": 0.125,
#     "rate": 2.898
#   },
#   "Movie 11": {
#     "home_ind": 0.2,
#     "weekends_ind": 0.225,
#     "rate": 3.308
#   },
#   "Movie 12": {
#     "home_ind": 0.3,
#     "weekends_ind": 0.2,
#     "rate": 3.308
#   },
#   "Movie 20": {
#     "home_ind": 0.325,
#     "weekends_ind": 0.15,
#     "rate": 2.299
#   },
#   "Movie 27": {
#     "home_ind": 0.225,
#     "weekends_ind": 0.3,
#     "rate": 2.918
#   },
#   "Movie 28": {
#     "home_ind": 0.25,
#     "weekends_ind": 0.25,
#     "rate": 2.284
#   }
# }

# %%
#Считаем total_rate, который получается из суммы rate, home_ind, weekends_ind
total_rate=0
for film in films.keys():
    total_rate=films[film]['home_ind']+films[film]['weekends_ind']+films[film]['rate']
    films[film]['total_rate']=round(total_rate,3)

# %%
print(json.dumps(films, indent=2))
# Out:
# {
#   "Movie 6": {
#     "home_ind": 0.2,
#     "weekends_ind": 0.125,
#     "rate": 2.898,
#     "total_rate": 3.223
#   },
#   "Movie 11": {
#     "home_ind": 0.2,
#     "weekends_ind": 0.225,
#     "rate": 3.308,
#     "total_rate": 3.733
#   },
#   "Movie 12": {
#     "home_ind": 0.3,
#     "weekends_ind": 0.2,
#     "rate": 3.308,
#     "total_rate": 3.808
#   },
#   "Movie 20": {
#     "home_ind": 0.325,
#     "weekends_ind": 0.15,
#     "rate": 2.299,
#     "total_rate": 2.774
#   },
#   "Movie 27": {
#     "home_ind": 0.225,
#     "weekends_ind": 0.3,
#     "rate": 2.918,
#     "total_rate": 3.443
#   },
#   "Movie 28": {
#     "home_ind": 0.25,
#     "weekends_ind": 0.25,
#     "rate": 2.284,
#     "total_rate": 2.784
#   }
# }

# %%
#Находим фильм с максимальным total_rate
maximum=-1
for film in films.keys():
    if (maximum<films[film]['total_rate']):
        maximum=films[film]['total_rate']
        rec_film=film
print(rec_film)
# Out:
# Movie 12

# %%
recommended_film={}
recommended_film[rec_film]=maximum

# %%
#Фильм для рекомендации с новым рейтингом
recommended_film
# Out:
# {'Movie 12': 3.808}

# %%
#Записываем результат в json
result = {
    'user': user15,
    '1': rates,
    '2': recommended_film
}

with open('result.json', 'w') as file:
    json.dump(result,file,indent=2)
    
print(json.dumps(result,indent=2))
# Out:
# {
#   "user": 15,
#   "1": {
#     "Movie 6": 2.898,
#     "Movie 11": 3.308,
#     "Movie 12": 3.308,
#     "Movie 20": 2.299,
#     "Movie 27": 2.918,
#     "Movie 28": 2.284
#   },
#   "2": {
#     "Movie 12": 3.808
#   }
# }
